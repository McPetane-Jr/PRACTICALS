# %% [markdown]
# # My Solutions
#
# # Functions

# %% [markdown]
# ---

# %% [markdown]
# ### Part 1
# #### My Solution

# %%
def list_benefits():
    return ["More organized code", "More readable code", "Easier code reuse", "Allowing programmers to share and connect code together"]

def build_sentence(benefit):
    return str(benefit) + " is a benefit of functions!"

def name_the_benefits_of_functions():
    list_of_benefits = list_benefits()
    for benefit in list_of_benefits:
        print(build_sentence(benefit))

name_the_benefits_of_functions()
# Out:
# More organized code is a benefit of functions!
# More readable code is a benefit of functions!
# Easier code reuse is a benefit of functions!
# Allowing programmers to share and connect code together is a benefit of functions!

# %% [markdown]
# ### "Correct Solution"

# %%
# Modify this function to return a list of strings as defined above
def list_benefits():
    return "More organized code", "More readable code", "Easier code reuse", "Allowing programmers to share and connect code together"

# Modify this function to concatenate to each benefit - " is a benefit of functions!"
def build_sentence(benefit):
    return "%s is a benefit of functions!" % benefit


def name_the_benefits_of_functions():
    list_of_benefits = list_benefits()
    for benefit in list_of_benefits:
        print(build_sentence(benefit))

name_the_benefits_of_functions()
# Out:
# More organized code is a benefit of functions!
# More readable code is a benefit of functions!
# Easier code reuse is a benefit of functions!
# Allowing programmers to share and connect code together is a benefit of functions!

# %% [markdown]
# ### Debrief

# %% [markdown]
# #### Duration
# This section took close to an hour but the only reason for that was my pace and the fact that I was still getting used to typing in https://www.learnpython.org/
#
# #### Understanding
# Yes, I managed to understand the tutorial at the end.
#
# I still think the approach I took is correct, regardless of what the solution said to be correct is.

# %% [markdown]
# ---

# %% [markdown]
# ### Part 2:

# %% [markdown]
# #### 1. Sum of Resistance in Series Circuits - Easy
#
# ##### Instuction
#
# When resistors are connected together in series, the same current passes through each resistor in the chain and the total resistance, RT, of the circuit must be equal to the sum of all the individual resistors added together. That is:
# ```
# `RT = R1 + R2 + R3 ...
# ```
# Create a function that takes an array of values resistance that are connected in series, and calculates the total resistance of the circuit in ohms. The ohm is the standard unit of electrical resistance in the International System of Units ( SI ).
#
# Examples
# ```
# series_resistance([1, 5, 6, 3]) ➞ "15 ohms"
#
# series_resistance([16, 3.5, 6]) ➞ "25.5 ohms"
#
# series_resistance([0.5, 0.5]) ➞ "1.0 ohm"
# ```
# Notes
# All inputs will be valid.
# Notice the singular ohm for values <= 1.
# This challenge was inspired by Joshua Señoron's Python Sum of Resistance in Parallel Circuits challenge. You can find it here.
#
# ```
# def series_resistance(lst):
# ```
#
# ##### Duration:
# - This one took less than 2 minutes.
#
# ##### Dificulty:
# - Very easy
#
# ##### My solution

# %%
def series_resistance(lst):
  # if !len(lst): return
  rT=0
  for r in lst:
    rT+=r
  return f"{rT} ohms" if rT>1 else f"{rT} ohm"

# %% [markdown]
# #### 2. Radians to Degrees - Easy
#
# ##### Instuction
#
# Create a function that takes an angle in radians and returns the corresponding angle in degrees rounded to one decimal place.
#
# Examples
# ```
# radians_to_degrees(1) ➞ 57.3
#
# radians_to_degrees(20) ➞ 1145.9
#
# radians_to_degrees(50) ➞ 2864.8
# ```
#
# Notes
# - The number π can be loaded from the math module with from math import pi.
#
# ```
# def radians_to_degrees(rad):
# ```
#
# ##### Duration:
# - This one took less than 10 minutes.
#
# ##### Dificulty:
# - It was okay, the only thing that had me confused was the precision points and actually doing the math took more time than expexted.
#
#
# ##### My solution

# %%
def radians_to_degrees(rad):
  from math import pi
  return round(rad*180/pi,1)

# %% [markdown]
# #### 3. Find the Discount - Easy
#
# ##### Instuction
#
# Create a function that takes two arguments: the original price and the discount percentage as integers and returns the final price after the discount.
#
# Alternative Text
#
# Examples
# ```
# dis(1500, 50) ➞ 750
#
# dis(89, 20) ➞ 71.2
#
# dis(100, 75) ➞ 25
# ```
#
# Notes
# - Your answer should be rounded to two decimal places.
#
# ```
# def dis(price, discount):
# ```
#
# ##### Duration:
# - This one took less than 5 minutes.
#
# ##### Dificulty:
# - Very easy
#
# ##### My solution

# %%
def dis(price, discount):
 return round(price - (price*(discount/100)),2)

# %% [markdown]
# #### 4. Luke, I Am Your ... - Easy
#
# ##### Instuction
#
# Luke Skywalker has family and friends. Help him remind them who is who. Given a string with a name, return the relation of that person to Luke.
#
# Person ->	Relation
# Darth Vader ->	father
# Leia ->	sister
# Han ->	brother in law
# R2D2 ->	droid
# ##### Examples
# ```
# relation_to_luke("Darth Vader") ➞ "Luke, I am your father."
#
# relation_to_luke("Leia") ➞ "Luke, I am your sister."
#
# relation_to_luke("Han") ➞ "Luke, I am your brother in law."
# ```
#
# ##### Notes
# -
#
# ```
# def relation_to_luke(name):
# ```
#
# ##### Duration:
# - This one took roughly about 15 minutes.
#
# ##### Dificulty:
# - Normal, I don't think this was an easy one if you're still new to python.
#
#
# ##### My solution

# %%
def relation_to_luke(name):
  match name:
    case "Darth Vader":
      return "Luke, I am your father."
    case "Leia":
      return "Luke, I am your sister."
    case "Han":
      return "Luke, I am your brother in law."
    case "R2D2":
      return "Luke, I am your droid."
    case _:
      retun

# %% [markdown]
# #### 5. Stuttering Function - Easy
#
# ##### Instuction
#
# Write a function that stutters a word as if someone is struggling to read it. The first two letters are repeated twice with an ellipsis ... and space after each, and then the word is pronounced with a question mark ?.
#
# Examples
# ```
# stutter("incredible") ➞ "in... in... incredible?"
#
# stutter("enthusiastic") ➞ "en... en... enthusiastic?"
#
# stutter("outstanding") ➞ "ou... ou... outstanding?"
# ```
#
# Notes
# - Assume all input is in lower case and at least two characters long.
#
# ```
# def stutter(word):
# ```
#
# ##### Duration:
# - This one took roughly about 10 minutes.
#
# ##### Dificulty:
# - Easy, but needed a good understanding of string manipulation.
# ##### My solution

# %%
def stutter(word):
  prefix = word[slice(2)]
  return f"{prefix}... {prefix}... {word}?"

# %% [markdown]
# #### 6. Find the Perimeter of a Rectangle - Very Easy
#
# ##### Instuction
#
# Create a function that takes length and width and finds the perimeter of a rectangle.
#
# Examples
# ```
# find_perimeter(6, 7) ➞ 26
#
# find_perimeter(20, 10) ➞ 60
#
# find_perimeter(2, 9) ➞ 22
# ```
# Notes
#
# - Don't forget to return the result.
# - If you're stuck, find help in the Resources tab.
# - If you're really stuck, find solutions in the Solutions tab.
#
# ##### My solution

# %%
def find_perimeter(length, width):
  return 2*(length+width)

# %% [markdown]
# #### 7. Convert Minutes into Seconds - Easy
#
# ##### Instuction
#
# Write a function that takes an integer minutes and converts it to seconds.
#
# Examples
# ```
# convert(5) ➞ 300
#
# convert(3) ➞ 180
#
# convert(2) ➞ 120
# ```
# Notes
# - Don't forget to return the result.
# - If you get stuck on a challenge, find help in the Resources tab.
# - If you're really stuck, unlock solutions in the Solutions tab.
#
# ##### Duration:
# - This one took less than 5 minutes.
#
# ##### Dificulty:
# - Very Easy.
#
# ##### My solution

# %%
def convert(minutes):
  return (minutes)*60

# %% [markdown]
# #### 8. Maximum Edge of a Triangle - Easy
#
# ##### Instuction
#
# Create a function that finds the maximum range of a triangle's third edge, where the side lengths are all integers.
#
# Examples
# ```
# next_edge(8, 10) ➞ 17
#
# next_edge(5, 7) ➞ 11
#
# next_edge(9, 2) ➞ 10
# ```
#
# Notes
# - (side1 + side2) - 1 = maximum range of third edge.
# - The side lengths of the triangle are positive integers.
# - Don't forget to return the result.
#
# ##### Duration:
# - This one took roughly 2 minutes.
#
# ##### Dificulty:
# - Very easy.
#
# ##### My solution

# %%
def next_edge(side1, side2):
  return (side1+side2) -1

# %% [markdown]
# Please that the wording was vague, so I wasn't sure whether to do 3 or 15 challenges.

# %% [markdown]
# ---

# %% [markdown]
# ## Part 3: Reflection

# %% [markdown]
# I already had an understanding on how python works, besides it not being my language of choice. This assignment has helped prepare me for computational physics. The main topic I focused on was functions on learnpython.org and debugging, finding the maximum edge, sum of resistors in a circuit, radians to degrees and many more.
#
# These topics have broadened my knowledge in other areas such as match casing, precision points, string manipulation and other usefull concepts that I will most likely use when perfoming computaions on physical data.
#
# I'm definately planning on utilising these online platforms as I learn the language since they've proved to be helpful in learning new python concepts. The questions being asked make you consider the computaional approach to solving a problem, and not just the mathematics of it, which plays a huge role in physics and is something I plan on implementing in my career after University.

# %% [markdown]
# ---

# %% [markdown]
# ## Part 4
#
# - All necessary checks were made.

# %% [markdown]
# ---
